# %% [markdown]
# ![image.png](attachment:image.png)
#
# ``if you have the dataset and we need it in this shape so run it first``

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.6.1-py3-none-any.whl.metadata (11 kB)
# Downloading split_folders-0.6.1-py3-none-any.whl (13 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.6.1
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import splitfolders

input_folder = "PetImages"

output_folder = "dataset"

splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=42,  
    ratio=(0.8, 0.2),  # 80% train, 20% test
    group_prefix=None,
    move=True, 
)
# Out:
# Copying files: 24998 files [00:17, 1437.35 files/s]
